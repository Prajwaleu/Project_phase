# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_excel("Book1.xlsx")

# %%
df.head()
# Out:
#    Amount_of_Algae  Initial_Concentration  Absorbance         PPM  \
# 0              0.5                   1000        0.48  865.459118
# 1              1.0                   1000        0.42  739.450043
# 2              2.0                   1000        0.40  697.447018
# 3              3.0                   1000        0.37  634.442480
# 4              4.0                   1000        0.32  529.434918
#
#    Contact_time  PH  Removal Effeciency  Removal Effeciency.1
# 0            30   4            0.134541             13.454088
# 1            30   4            0.260550             26.054996
# 2            30   4            0.302553             30.255298
# 3            30   4            0.365558             36.555752
# 4            30   4            0.470565             47.056508

# %%
df.corr()
# Out:
#                        Amount_of_Algae  Initial_Concentration  Absorbance  \
# Amount_of_Algae           1.000000e+00           2.482566e-16   -0.397296
# Initial_Concentration     2.482566e-16           1.000000e+00    0.847040
# Absorbance               -3.972962e-01           8.470401e-01    1.000000
# PPM                      -3.974898e-01           8.468177e-01    0.999994
# Contact_time             -9.535994e-17           4.473894e-17   -0.195321
# PH                       -6.049624e-17          -4.392901e-16    0.038764
# Removal Effeciency        7.221190e-01          -3.664528e-01   -0.742727
# Removal Effeciency.1      7.221190e-01          -3.664528e-01   -0.742727
#
#                             PPM  Contact_time            PH  \
# Amount_of_Algae       -0.397490 -9.535994e-17 -6.049624e-17
# Initial_Concentration  0.846818  4.473894e-17 -4.392901e-16
# Absorbance             0.999994 -1.953207e-01  3.876443e-02
# PPM                    1.000000 -1.958065e-01  3.851217e-02
# Contact_time          -0.195806  1.000000e+00  2.990923e-16
# PH                     0.038512  2.990923e-16  1.000000e+00
# Removal Effeciency    -0.742954  3.588767e-01  1.009134e-01
# Removal Effeciency.1  -0.742954  3.588767e-01  1.009134e-01
#
#                        Removal Effeciency  Removal Effeciency.1
# Amount_of_Algae                  0.722119              0.722119
# Initial_Concentration           -0.366453             -0.366453
# Absorbance                      -0.742727             -0.742727
# PPM                             -0.742954             -0.742954
# Contact_time                     0.358877              0.358877
# PH                               0.100913              0.100913
# Removal Effeciency               1.000000              1.000000
# Removal Effeciency.1             1.000000              1.000000

# %%
import seaborn as sns
sns.displot(df)

# %%
sns.barplot(x='Amount_of_Algae',y='Removal Effeciency', data=df, 
            hue='Contact_time')
plt.show()

# %%
sns.barplot(x='Contact_time',y='Removal Effeciency',data=df,hue="Amount_of_Algae")
plt.show()

# %%
g = sns.FacetGrid(df, col='Initial_Concentration')
g = g.map(sns.kdeplot, 'Removal Effeciency')

# %%
sns.pairplot(df,size=2,diag_kind='kde')
# Out:
# C:\Users\dell3\anaconda3\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
plt.figure(figsize=(16, 6))
heatmap = sns.heatmap(df.corr(), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':18}, pad=12);

# %%
df.describe()
# Out:
#        Amount_of_Algae  Initial_Concentration  Absorbance         PPM  \
# count       120.000000             120.000000  120.000000  120.000000
# mean          2.583333             600.000000    0.223850  327.438681
# std           1.598757             284.028641    0.099059  207.981286
# min           0.500000             200.000000    0.078000   21.198316
# 25%           1.000000             400.000000    0.150000  172.409206
# 50%           2.500000             600.000000    0.210000  298.418281
# 75%           4.000000             800.000000    0.290000  466.430381
# max           5.000000            1000.000000    0.480000  865.459118
#
#        Contact_time          PH  Removal Effeciency  Removal Effeciency.1
# count    120.000000  120.000000          120.000000            120.000000
# mean      75.000000    3.600000            0.486486             48.648621
# std       33.681653    0.491952            0.187282             18.728158
# min       30.000000    3.000000            0.101939             10.193934
# 25%       52.500000    3.000000            0.356214             35.621367
# 50%       75.000000    4.000000            0.467634             46.763368
# 75%       97.500000    4.000000            0.622855             62.285486
# max      120.000000    4.000000            0.894008             89.400842

# %%
x=df.iloc[:,:6]
y=df.iloc[:,6]

# %%
x
# Out:
#      Amount_of_Algae  Initial_Concentration  Absorbance         PPM  \
# 0                0.5                   1000       0.480  865.459118
# 1                1.0                   1000       0.420  739.450043
# 2                2.0                   1000       0.400  697.447018
# 3                3.0                   1000       0.370  634.442480
# 4                4.0                   1000       0.320  529.434918
# ..               ...                    ...         ...         ...
# 115              1.0                    200       0.100   67.401644
# 116              2.0                    200       0.090   46.400131
# 117              3.0                    200       0.089   44.299980
# 118              4.0                    200       0.085   35.899375
# 119              5.0                    200       0.080   25.398619
#
#      Contact_time  PH
# 0              30   4
# 1              30   4
# 2              30   4
# 3              30   4
# 4              30   4
# ..            ...  ..
# 115           120   4
# 116           120   4
# 117           120   4
# 118           120   4
# 119           120   4
#
# [120 rows x 6 columns]

# %%
y
# Out:
# 0      0.134541
# 1      0.260550
# 2      0.302553
# 3      0.365558
# 4      0.470565
#          ...
# 115    0.662992
# 116    0.767999
# 117    0.778500
# 118    0.820503
# 119    0.873007
# Name: Removal Effeciency, Length: 120, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=0,test_size=0.3)

# %%
# Fitting Simple Linear Regression to the Training set
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# Predicting the Test set results
y_pred = regressor.predict(x_test)

# %%
plt.scatter(y_test,y_pred);
plt.xlabel('Actual');
plt.ylabel('Predicted');

# %%
pred_df=pd.DataFrame({'Actual Value':y_test,'Predicted Value':y_pred,'Difference':y_test-y_pred})

# %%
pred_df
# Out:
#      Actual Value  Predicted Value  Difference
# 48       0.187614         0.261543   -0.073929
# 94       0.621481         0.631283   -0.009802
# 95       0.673985         0.684896   -0.010911
# 8        0.344556         0.310930    0.033626
# 97       0.452977         0.495905   -0.042928
# 22       0.575573         0.636109   -0.060536
# 7        0.323554         0.257316    0.066238
# 10       0.491567         0.514649   -0.023083
# 45       0.653229         0.611349    0.041881
# 89       0.621481         0.643465   -0.021984
# 33       0.521970         0.470591    0.051379
# 50       0.257619         0.351612   -0.093993
# 2        0.302553         0.250200    0.052353
# 60       0.257619         0.344405   -0.086786
# 119      0.873007         0.776753    0.096253
# 74       0.306458         0.380465   -0.074007
# 30       0.154443         0.114622    0.039821
# 43       0.390710         0.349732    0.040978
# 111      0.767999         0.666694    0.101306
# 76       0.411466         0.487691   -0.076226
# 63       0.467634         0.545983   -0.078349
# 59       0.537639         0.631077   -0.093438
# 16       0.533570         0.575379   -0.041809
# 24       0.101939         0.053893    0.048047
# 110      0.662992         0.613081    0.049911
# 13       0.365558         0.318046    0.047511
# 54       0.222616         0.302974   -0.080358
# 93       0.568977         0.577669   -0.008692
# 26       0.338206         0.279053    0.059153
# 68       0.537639         0.572398   -0.034760
# 51       0.327624         0.424524   -0.096900
# 113      0.820503         0.744972    0.075531
# 107      0.894008         0.736349    0.157660
# 61       0.362626         0.419458   -0.056832
# 3        0.365558         0.342411    0.023147
# 96       0.242962         0.440150   -0.197188

# %%
#shapes of splitted data
print("X_train:",x_train.shape)
print("X_test:",x_test.shape)
print("Y_train:",y_train.shape)
print("Y_test:",y_test.shape)
# Out:
# X_train: (84, 6)
# X_test: (36, 6)
# Y_train: (84,)
# Y_test: (36,)

# %% [markdown]
# #To train the model, we have to import the Linear Regression model, which we have already created at the beginning. Use the fit method, and pass the training sets into it to train the model.

# %%
from sklearn.metrics import r2_score
Accuracy=r2_score(y_test,y_pred)*100
print(" Accuracy of the model is %.2f" %Accuracy)
# Out:
#  Accuracy of the model is 86.57

# %% [markdown]
# # ACCURACY OF LINEAR REGRESSION MODEL IS 86.57

# %%
import tensorflow as tf

# %%
#Performing Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %% [markdown]
# Here we have used StandardScalar class from the sklearn library in order to perform standardization.
#
# Now we have completed our feature engineering phase. We can now start with the creation of our artificial neural network from the next point onwards.

# %%
#Initialising ANN
ann = tf.keras.models.Sequential()

# %%
 #Adding First Hidden Layer
ann.add(tf.keras.layers.Dense(units=6,activation="relu"))

# %% [markdown]
# Here we have created our first hidden layer by using the Dense class which is part of the layers module. This class accepts 2 inputs:-
#
# 1. units:- number of neurons that will be present in the respective layer
#
# 2. activation:- specify which activation function to be used
#
# For the first input, I had tested with many values in the past and the optimal value that I had found is 6. Obviously, we can try with any other value as there is no hard rule about the number of neurons that should be present in the layer.
#
# For the second input, we are always going to use “relu”[rectified linear unit] as an activation function for hidden layers. Since we are going to create two hidden layers, this same step we are going to repeat for the creation of the second hidden layer as well.

# %%
#Adding Second Hidden Layer
ann.add(tf.keras.layers.Dense(units=6,activation="relu"))

# %%
 #Adding Output Layer
ann.add(tf.keras.layers.Dense(units=1,activation="sigmoid"))

# %%
#Compiling ANN
ann.compile(optimizer="adam",loss="binary_crossentropy",metrics=['accuracy'])

# %% [markdown]
# 1. optimizer:- specifies which optimizer to be used in order to perform stochastic gradient descent. I had experimented with various optimizers like RMSProp, adam and I have found that adam optimizer is a reliable one that can be used with any neural network.
#
#
# 2. loss:- specifies which loss function should be used. For binary classification, the value should be binary_crossentropy. For multiclass classification, it should be categorical_crossentropy.
#
#
# 3. metrics:- which performance metrics to be used in order to compute performance. Here we have used accuracy as a performance metric

# %%
#Fitting ANN
ann.fit(x_train,y_train,batch_size=32,epochs = 100)
# Out:
# Epoch 1/100
# 3/3 [==============================] - 1s 2ms/step - loss: 0.7481 - accuracy: 0.0000e+00
# Epoch 2/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7413 - accuracy: 0.0000e+00
# Epoch 3/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7344 - accuracy: 0.0000e+00
# Epoch 4/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7303 - accuracy: 0.0000e+00
# Epoch 5/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7239 - accuracy: 0.0000e+00
# Epoch 6/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7198 - accuracy: 0.0000e+00
# Epoch 7/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7146 - accuracy: 0.0000e+00
# Epoch 8/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7099 - accuracy: 0.0000e+00
# Epoch 9/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7058 - accuracy: 0.0000e+00
# Epoch 10/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7025 - accuracy: 0.0000e+00
# Epoch 11/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6989 - accuracy: 0.0000e+00
# Epoch 12/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6953 - accuracy: 0.0000e+00
# Epoch 13/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6922 - accuracy: 0.0000e+00
# Epoch 14/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6893 - accuracy: 0.0000e+00
# Epoch 15/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6869 - accuracy: 0.0000e+00
# Epoch 16/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6841 - accuracy: 0.0000e+00
# Epoch 17/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6815 - accuracy: 0.0000e+00
# Epoch 18/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6794 - accuracy: 0.0000e+00
# Epoch 19/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6771 - accuracy: 0.0000e+00
# Epoch 20/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6754 - accuracy: 0.0000e+00
# Epoch 21/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6740 - accuracy: 0.0000e+00
# Epoch 22/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6720 - accuracy: 0.0000e+00
# Epoch 23/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6705 - accuracy: 0.0000e+00
# Epoch 24/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6690 - accuracy: 0.0000e+00
# Epoch 25/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6679 - accuracy: 0.0000e+00
# Epoch 26/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6668 - accuracy: 0.0000e+00
# Epoch 27/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6655 - accuracy: 0.0000e+00
# Epoch 28/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6645 - accuracy: 0.0000e+00
# Epoch 29/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6634 - accuracy: 0.0000e+00
# Epoch 30/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6624 - accuracy: 0.0000e+00
# Epoch 31/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6616 - accuracy: 0.0000e+00
# Epoch 32/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6607 - accuracy: 0.0000e+00
# Epoch 33/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6599 - accuracy: 0.0000e+00
# Epoch 34/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6592 - accuracy: 0.0000e+00
# Epoch 35/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6584 - accuracy: 0.0000e+00
# Epoch 36/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6577 - accuracy: 0.0000e+00
# Epoch 37/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6570 - accuracy: 0.0000e+00
# Epoch 38/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6563 - accuracy: 0.0000e+00
# Epoch 39/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6557 - accuracy: 0.0000e+00
# Epoch 40/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6551 - accuracy: 0.0000e+00
# Epoch 41/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6546 - accuracy: 0.0000e+00
# Epoch 42/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6540 - accuracy: 0.0000e+00
# Epoch 43/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6535 - accuracy: 0.0000e+00
# Epoch 44/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6531 - accuracy: 0.0000e+00
# Epoch 45/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6525 - accuracy: 0.0000e+00
# Epoch 46/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6520 - accuracy: 0.0000e+00
# Epoch 47/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6516 - accuracy: 0.0000e+00
# Epoch 48/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6511 - accuracy: 0.0000e+00
# Epoch 49/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6506 - accuracy: 0.0000e+00
# Epoch 50/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6501 - accuracy: 0.0000e+00
# Epoch 51/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6497 - accuracy: 0.0000e+00
# Epoch 52/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6492 - accuracy: 0.0000e+00
# Epoch 53/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6489 - accuracy: 0.0000e+00
# Epoch 54/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6484 - accuracy: 0.0000e+00
# Epoch 55/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6480 - accuracy: 0.0000e+00
# Epoch 56/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6475 - accuracy: 0.0000e+00
# Epoch 57/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6470 - accuracy: 0.0000e+00
# Epoch 58/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6466 - accuracy: 0.0000e+00
# Epoch 59/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6461 - accuracy: 0.0000e+00
# Epoch 60/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6456 - accuracy: 0.0000e+00
# Epoch 61/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6449 - accuracy: 0.0000e+00
# Epoch 62/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6442 - accuracy: 0.0000e+00
# Epoch 63/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6436 - accuracy: 0.0000e+00
# Epoch 64/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6430 - accuracy: 0.0000e+00
# Epoch 65/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6425 - accuracy: 0.0000e+00
# Epoch 66/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6419 - accuracy: 0.0000e+00
# Epoch 67/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6414 - accuracy: 0.0000e+00
# Epoch 68/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6410 - accuracy: 0.0000e+00
# Epoch 69/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6405 - accuracy: 0.0000e+00
# Epoch 70/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6401 - accuracy: 0.0000e+00
# Epoch 71/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6397 - accuracy: 0.0000e+00
# Epoch 72/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6393 - accuracy: 0.0000e+00
# Epoch 73/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6389 - accuracy: 0.0000e+00
# Epoch 74/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6386 - accuracy: 0.0000e+00
# Epoch 75/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6382 - accuracy: 0.0000e+00
# Epoch 76/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6379 - accuracy: 0.0000e+00
# Epoch 77/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6376 - accuracy: 0.0000e+00
# Epoch 78/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6373 - accuracy: 0.0000e+00
# Epoch 79/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6370 - accuracy: 0.0000e+00
# Epoch 80/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6368 - accuracy: 0.0000e+00
# Epoch 81/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6366 - accuracy: 0.0000e+00
# Epoch 82/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6364 - accuracy: 0.0000e+00
# Epoch 83/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6361 - accuracy: 0.0000e+00
# Epoch 84/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6359 - accuracy: 0.0000e+00
# Epoch 85/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6357 - accuracy: 0.0000e+00
# Epoch 86/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6355 - accuracy: 0.0000e+00
# Epoch 87/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6353 - accuracy: 0.0000e+00
# Epoch 88/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6351 - accuracy: 0.0000e+00
# Epoch 89/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6350 - accuracy: 0.0000e+00
# Epoch 90/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6348 - accuracy: 0.0000e+00
# Epoch 91/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6346 - accuracy: 0.0000e+00
# Epoch 92/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6345 - accuracy: 0.0000e+00
# Epoch 93/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6344 - accuracy: 0.0000e+00
# Epoch 94/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6342 - accuracy: 0.0000e+00
# Epoch 95/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6340 - accuracy: 0.0000e+00
# Epoch 96/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6339 - accuracy: 0.0000e+00
# Epoch 97/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6338 - accuracy: 0.0000e+00
# Epoch 98/100
# 3/3 [==============================] - 0s 997us/step - loss: 0.6336 - accuracy: 0.0000e+00
# Epoch 99/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6335 - accuracy: 0.0000e+00
# Epoch 100/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6334 - accuracy: 0.0000e+00
